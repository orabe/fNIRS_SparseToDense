# %%
# !nvidia-smi
# Out:
# Wed Dec 17 20:27:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-PCIE-40GB          On  |   00000000:06:00.0 Off |                    0 |
# | N/A   33C    P0             35W /  250W |     475MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A         1226735      C   ...onda/envs/cedalion/bin/python        466MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Load Modules

# %%
import os
import sys
import numpy as np
import xarray as xr
import pyvista as pv
pv.set_jupyter_backend("html")
from cedalion import units
import cedalion
import pickle
import glob 
from pathlib import Path
from pathlib import PureWindowsPath
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from pathlib import Path

# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
def max_value_normalize(xarr):
    """
    Normalizes an xarray DataArray by dividing by the maximum absolute value of chromo=0,
    scaling the data into the (-1,1) range.

    Parameters:
        xarr (xarray.DataArray): Input data with chromo x parcel x time dimensions.
    Returns:
        xarray.DataArray: Normalized data in the range (-1,1).
    """
    # Extract chromo=0, HbO
    chromo_0 = xarr[:, :, :] # TODO consider both hbo and hbr. plot distr
    
    # Get the maximum absolute value from chromo=0
    max_val = np.abs(chromo_0).max()

    # Avoid division by zero
    if max_val == 0:
        return xarr  # Return unchanged if max is zero
    
    # Normalize
    normalized = xarr / max_val

    return xr.DataArray(normalized, coords=xarr.coords, dims=xarr.dims), max_val

# %%
# Available datasets:
# DATASET_NAME = "BallSqueezingHD_modified"
# DATASET_NAME = "BS_Laura"
DATASET_NAME = "FreshMotor"
# DATASET_NAME = "ElectricalThermal"


PRE_PROCESSED_DIR = Path(f'datasets/preprocessed/{DATASET_NAME}')
preproc_files_path = str(PRE_PROCESSED_DIR / 'ts_all_parcels' / 'sub-*' / '*.pkl')
pkl_files = glob.glob(preproc_files_path)

len(pkl_files), pkl_files[:2]
# Out:
# (40,
#  ['datasets/preprocessed/FreshMotor/ts_all_parcels/sub-08/sub-08_task-FRESHMOTOR_run-left2s_nirs_ts_all_parcels.pkl',
#   'datasets/preprocessed/FreshMotor/ts_all_parcels/sub-08/sub-08_task-FRESHMOTOR_run-right2s_nirs_ts_all_parcels.pkl'])

# %%
PROCESSED_DIR = Path(f'datasets/processed/{DATASET_NAME}')
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Create a templete parcels based on BallSqueezing dataset

# %%
if DATASET_NAME == "BallSqueezingHD_modified":
    MAX_PARCELS = 0
    PARCEL_TEMPLATE = None

    for file in pkl_files:
        with open(file, 'rb') as handle:
            data_pickle = pickle.load(handle)        
        timeseries = data_pickle['signal_raw']
        sensitive_parcels = data_pickle['sensitive_parcels']
        
        sensitive_timeseries = timeseries.sel(parcel=sensitive_parcels)
        
        if sensitive_timeseries.sizes["parcel"] > MAX_PARCELS:
            MAX_PARCELS = sensitive_timeseries.sizes["parcel"]
            PARCEL_TEMPLATE = sensitive_timeseries.parcel.values.tolist()
            
    
    print(f"Max parcels across subjects: {MAX_PARCELS}")
    print(f"Parcel template: {PARCEL_TEMPLATE}")

    # Save the template parcels to pkl file
    with open(f'{PROCESSED_DIR}/parcel_template_{DATASET_NAME}.pkl', 'wb') as handle:
        pickle.dump(PARCEL_TEMPLATE, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Load Pre-defined template parcel

# %%
# Load Pre-defined template parcel from BallSqueezingHD_modified pkl file
with open(f'{PROCESSED_DIR.parents[0]}/BallSqueezingHD_modified/parcel_template_BallSqueezingHD_modified.pkl', 'rb') as handle:
    PARCEL_TEMPLATE = pickle.load(handle)
len(PARCEL_TEMPLATE)
# Out:
# 109

# %% [markdown]
# # Inspect parcels

# %% [markdown]
# ## Load files for testing

# %%
freqs = [0.5, 0.7, 1.0] 
FMAX = freqs[0]
# freq_dir = PROCESSED_DIR / f'frq{0.2}'
# freq_dir.mkdir(exist_ok=True)
    
sensitive_parcels_list = []

for file in pkl_files:
    with open(file, 'rb') as handle:
        data_pickle = pickle.load(handle)
        
    timeseries = data_pickle['signal_raw']
    sensitive_parcels = data_pickle['sensitive_parcels']
    
    sensitive_parcels_list.append(sensitive_parcels)
    
for i in sensitive_parcels_list:
    print(len(i), end=', ')
    
plt.hist([len(i) for i in sensitive_parcels_list], bins=20)
plt.xlabel('Number of Sensitive Parcels')
plt.ylabel('Counts')
plt.title(f'{DATASET_NAME} - Distribution of Sensitive Parcels Across Subjects/Sessions')
plt.savefig(PROCESSED_DIR / f'sensitive_parcels_distribution_{DATASET_NAME}.png', dpi=300)
plt.show()
# Out:
# 170, 176, 170, 176, 161, 165, 161, 156, 167, 167, 82, 75, 174, 174, 169, 169, 155, 155, 155, 155, 164, 159, 159, 159, 164, 164, 152, 152, 158, 160, 160, 160, 175, 171, 171, 171, 172, 172, 172, 172,

# %%
# load first file
with open(pkl_files[9], 'rb') as handle:
    data_pickle = pickle.load(handle)
    
timeseries = data_pickle['signal_raw']
dropped_parcels = data_pickle['dropped_parcels']
sensitive_parcels = data_pickle['sensitive_parcels']
len(sensitive_parcels), len(dropped_parcels), timeseries.shape
# Out:
# (167, 435, (2, 601, 4332))

# %% [markdown]
# ### Inspect shape of original parcels and sens_parcels of 1st file

# %%
print("timeseries.shape:", timeseries.shape)
print("len(sensitive_parcels):", len(sensitive_parcels))
print("len(PARCEL_TEMPLATE):", len(PARCEL_TEMPLATE))
print("timeseries.sel(parcel=PARCEL_TEMPLATE).shape:", timeseries.sel(parcel=PARCEL_TEMPLATE).shape)
# Out:
# timeseries.shape: (2, 601, 4332)
# len(sensitive_parcels): 167
# len(PARCEL_TEMPLATE): 109
# timeseries.sel(parcel=PARCEL_TEMPLATE).shape: (2, 109, 4332)

# %%
signal_raw = timeseries.transpose('parcel', "chromo", "time")
signal_raw = signal_raw.pint.quantify({'time':'seconds'})
signal_raw.sel(chromo='HbO', parcel=PARCEL_TEMPLATE)
# Out:
# <xarray.DataArray (parcel: 109, time: 4332)> Size: 4MB
# <Quantity([[ 7.80693330e-02 -4.43770646e-02 -4.07250195e-02 ...  6.59893296e-02
#    3.19565558e-01  1.03178834e-01]
#  [-1.98711516e-03  3.31907359e-03  8.32653587e-04 ... -1.97886259e-02
#   -3.14327475e-02 -1.26727333e-02]
#  [ 2.37485918e-02 -4.79207724e-03 -1.29047997e-02 ...  1.38051333e-02
#    7.36938412e-02  1.84085414e-02]
#  ...
#  [-6.60471262e-03  5.45868840e-04 -1.20970208e-02 ... -1.35890137e-02
#   -1.87244929e-02 -1.32261355e-02]
#  [ 1.03572963e-03  4.35378386e-04  1.11829019e-03 ...  2.77310659e-04
#   -1.35660787e-03 -8.99018655e-04]
#  [-2.02592451e-02 -1.77723578e-04 -6.87815389e-03 ... -1.88939414e-02
#   -4.01793884e-02 -2.65295838e-02]], 'micromolar')>
# Coordinates:
#     chromo   <U3 12B 'HbO'
#   * time     (time) float64 35kB 0.0 0.112 0.224 0.336 ... 484.8 485.0 485.1
#     samples  (time) int64 35kB 0 1 2 3 4 5 6 ... 4326 4327 4328 4329 4330 4331
#   * parcel   (parcel) object 872B 'ContA_IPS_2_LH' ... 'TempPar_8_LH'

# %% [markdown]
# ### Inspect ensitive parcels of first file

# %% [markdown]
# ### Reindex
# - filter1: keep only sensitive parcels of that file
# - filter2: filter with template parcels
# - reindex: zero pad

# %%
padded_timeseries = timeseries.sel(parcel=sensitive_parcels).reindex(parcel=PARCEL_TEMPLATE, fill_value=0)

padded_timeseries.shape, padded_timeseries[:, 0, 0].values
# Out:
# ((2, 109, 4332), array([ 0.07806933, -0.00864547]))

# %% [markdown]
# ### Check the template parcels

# %%
for i, parcel in enumerate(PARCEL_TEMPLATE):
        print(f"{i}. {parcel}")
# Out:
# 0. ContA_IPS_2_LH
# 1. ContA_IPS_2_RH
# 2. ContA_IPS_3_LH
# 3. ContA_IPS_3_RH
# 4. ContA_PFCd_1_LH
# 5. ContA_PFCd_2_LH
# 6. ContA_PFCl_1_LH
# 7. ContA_PFCl_2_LH
# 8. ContA_PFCl_2_RH
# 9. ContA_PFCl_5_RH
# 10. ContA_PFCl_6_LH
# 11. ContB_IPL_3_LH
# 12. ContB_IPL_3_RH
# 13. ContB_PFCd_1_LH
# 14. ContB_PFCl_1_LH
# 15. ContB_PFCld_2_RH
# 16. ContB_PFCld_3_RH
# 17. ContB_PFCld_4_RH
# 18. ContB_PFCld_5_RH
# 19. ContB_PFCld_6_RH
# 20. DefaultB_IPL_3_LH
# 21. DefaultB_PFCl_1_LH
# 22. DefaultB_PFCl_2_LH
# 23. DefaultB_Temp_2_RH
# 24. DefaultB_Temp_5_LH
# 25. DorsAttnA_SPL_7_RH
# 26. DorsAttnB_FEF_1_LH
# 27. DorsAttnB_FEF_1_RH
# 28. DorsAttnB_FEF_2_RH
# 29. DorsAttnB_FEF_4_LH
# 30. DorsAttnB_FEF_4_RH
# 31. DorsAttnB_PostC_1_LH
# 32. DorsAttnB_PostC_1_RH
# 33. DorsAttnB_PostC_2_RH
# 34. DorsAttnB_PostC_3_LH
# 35. DorsAttnB_PostC_3_RH
# 36. DorsAttnB_PostC_4_RH
# 37. DorsAttnB_PrCv_1_LH
# 38. DorsAttnB_PrCv_1_RH
# 39. SalVentAttnA_FrOper_3_LH
# 40. SalVentAttnA_FrOper_3_RH
# 41. SalVentAttnA_FrOper_5_RH
# 42. SalVentAttnA_ParOper_1_RH
# 43. SalVentAttnA_ParOper_2_LH
# 44. SalVentAttnA_ParOper_3_LH
# 45. SalVentAttnA_ParOper_3_RH
# 46. SalVentAttnA_ParOper_4_RH
# 47. SalVentAttnA_ParOper_5_LH
# 48. SalVentAttnA_ParOper_5_RH
# 49. SalVentAttnA_PrC_1_RH
# 50. SalVentAttnB_IPL_1_RH
# 51. SalVentAttnB_IPL_2_RH
# 52. SalVentAttnB_Ins_4_RH
# 53. SalVentAttnB_PFCd_1_RH
# 54. SomMotA_10_LH
# 55. SomMotA_10_RH
# 56. SomMotA_11_RH
# 57. SomMotA_12_RH
# 58. SomMotA_13_RH
# 59. SomMotA_14_LH
# 60. SomMotA_14_RH
# 61. SomMotA_16_LH
# 62. SomMotA_17_RH
# 63. SomMotA_18_RH
# 64. SomMotA_1_LH
# 65. SomMotA_1_RH
# 66. SomMotA_2_RH
# 67. SomMotA_3_LH
# 68. SomMotA_3_RH
# 69. SomMotA_4_LH
# 70. SomMotA_4_RH
# 71. SomMotA_5_LH
# 72. SomMotA_6_RH
# 73. SomMotA_7_LH
# 74. SomMotA_7_RH
# 75. SomMotA_8_RH
# 76. SomMotA_9_LH
# 77. SomMotB_Aud_1_LH
# 78. SomMotB_Aud_1_RH
# 79. SomMotB_Aud_2_LH
# 80. SomMotB_Aud_2_RH
# 81. SomMotB_Aud_4_LH
# 82. SomMotB_Aud_4_RH
# 83. SomMotB_Aud_6_LH
# 84. SomMotB_Cent_1_LH
# 85. SomMotB_Cent_1_RH
# 86. SomMotB_Cent_2_LH
# 87. SomMotB_Cent_2_RH
# 88. SomMotB_Cent_3_LH
# 89. SomMotB_Cent_3_RH
# 90. SomMotB_Cent_4_LH
# 91. SomMotB_Cent_4_RH
# 92. SomMotB_Cent_5_LH
# 93. SomMotB_Cent_5_RH
# 94. SomMotB_Cent_6_LH
# 95. SomMotB_Cent_7_LH
# 96. SomMotB_S2_5_LH
# 97. SomMotB_S2_6_LH
# 98. SomMotB_S2_6_RH
# 99. SomMotB_S2_8_LH
# 100. SomMotB_S2_8_RH
# 101. TempPar_11_RH
# 102. TempPar_12_RH
# 103. TempPar_1_LH
# 104. TempPar_2_LH
# 105. TempPar_3_LH
# 106. TempPar_5_LH
# 107. TempPar_6_RH
# 108. TempPar_8_LH

# %% [markdown]
# ### Before padding: parcels of sensitive parcels of 1st file after before filtering with template parcels

# %%
for i, parcel in enumerate(PARCEL_TEMPLATE):
    if parcel in timeseries.sel(parcel=sensitive_parcels).parcel.values.tolist():
        print(f"{i}. {parcel}")
    else:
        print(f"{i}. {'----------------'}")
# Out:
# 0. ContA_IPS_2_LH
# 1. ContA_IPS_2_RH
# 2. ContA_IPS_3_LH
# 3. ContA_IPS_3_RH
# 4. ContA_PFCd_1_LH
# 5. ContA_PFCd_2_LH
# 6. ContA_PFCl_1_LH
# 7. ContA_PFCl_2_LH
# 8. ContA_PFCl_2_RH
# 9. ContA_PFCl_5_RH
# 10. ContA_PFCl_6_LH
# 11. ContB_IPL_3_LH
# 12. ContB_IPL_3_RH
# 13. ContB_PFCd_1_LH
# 14. ContB_PFCl_1_LH
# 15. ContB_PFCld_2_RH
# 16. ContB_PFCld_3_RH
# 17. ContB_PFCld_4_RH
# 18. ContB_PFCld_5_RH
# 19. ContB_PFCld_6_RH
# 20. DefaultB_IPL_3_LH
# 21. DefaultB_PFCl_1_LH
# 22. DefaultB_PFCl_2_LH
# 23. ----------------
# 24. ----------------
# 25. DorsAttnA_SPL_7_RH
# 26. DorsAttnB_FEF_1_LH
# 27. DorsAttnB_FEF_1_RH
# 28. DorsAttnB_FEF_2_RH
# 29. DorsAttnB_FEF_4_LH
# 30. DorsAttnB_FEF_4_RH
# 31. DorsAttnB_PostC_1_LH
# 32. DorsAttnB_PostC_1_RH
# 33. DorsAttnB_PostC_2_RH
# 34. DorsAttnB_PostC_3_LH
# 35. DorsAttnB_PostC_3_RH
# 36. DorsAttnB_PostC_4_RH
# 37. DorsAttnB_PrCv_1_LH
# 38. DorsAttnB_PrCv_1_RH
# 39. ----------------
# 40. ----------------
# 41. SalVentAttnA_FrOper_5_RH
# 42. SalVentAttnA_ParOper_1_RH
# 43. SalVentAttnA_ParOper_2_LH
# 44. SalVentAttnA_ParOper_3_LH
# 45. SalVentAttnA_ParOper_3_RH
# 46. SalVentAttnA_ParOper_4_RH
# 47. SalVentAttnA_ParOper_5_LH
# 48. SalVentAttnA_ParOper_5_RH
# 49. SalVentAttnA_PrC_1_RH
# 50. SalVentAttnB_IPL_1_RH
# 51. SalVentAttnB_IPL_2_RH
# 52. SalVentAttnB_Ins_4_RH
# 53. SalVentAttnB_PFCd_1_RH
# 54. SomMotA_10_LH
# 55. SomMotA_10_RH
# 56. SomMotA_11_RH
# 57. SomMotA_12_RH
# 58. SomMotA_13_RH
# 59. SomMotA_14_LH
# 60. SomMotA_14_RH
# 61. SomMotA_16_LH
# 62. SomMotA_17_RH
# 63. SomMotA_18_RH
# 64. SomMotA_1_LH
# 65. SomMotA_1_RH
# 66. SomMotA_2_RH
# 67. SomMotA_3_LH
# 68. SomMotA_3_RH
# 69. SomMotA_4_LH
# 70. SomMotA_4_RH
# 71. SomMotA_5_LH
# 72. SomMotA_6_RH
# 73. SomMotA_7_LH
# 74. SomMotA_7_RH
# 75. SomMotA_8_RH
# 76. SomMotA_9_LH
# 77. ----------------
# 78. ----------------
# 79. ----------------
# 80. ----------------
# 81. SomMotB_Aud_4_LH
# 82. SomMotB_Aud_4_RH
# 83. SomMotB_Aud_6_LH
# 84. SomMotB_Cent_1_LH
# 85. SomMotB_Cent_1_RH
# 86. SomMotB_Cent_2_LH
# 87. SomMotB_Cent_2_RH
# 88. SomMotB_Cent_3_LH
# 89. SomMotB_Cent_3_RH
# 90. SomMotB_Cent_4_LH
# 91. SomMotB_Cent_4_RH
# 92. SomMotB_Cent_5_LH
# 93. SomMotB_Cent_5_RH
# 94. SomMotB_Cent_6_LH
# 95. SomMotB_Cent_7_LH
# 96. ----------------
# 97. ----------------
# 98. ----------------
# 99. ----------------
# 100. SomMotB_S2_8_RH
# 101. TempPar_11_RH
# 102. TempPar_12_RH
# 103. ----------------
# 104. ----------------
# 105. ----------------
# 106. TempPar_5_LH
# 107. TempPar_6_RH
# 108. TempPar_8_LH

# %% [markdown]
# ### After padding: check parcels of 1st file after padding with template parcels

# %%
for i, parcel in enumerate(PARCEL_TEMPLATE):
    if parcel in padded_timeseries.parcel.values.tolist():
        print(f"{i}. {parcel}: {padded_timeseries.sel(parcel=parcel, chromo='HbO').values[0]}")
    else:
        print(f"{i}. {'----------------'}", end="")
# Out:
# 0. ContA_IPS_2_LH: 0.07806933296697559
# 1. ContA_IPS_2_RH: -0.00198711516032162
# 2. ContA_IPS_3_LH: 0.023748591789199303
# 3. ContA_IPS_3_RH: 0.0018797145605934777
# 4. ContA_PFCd_1_LH: -0.0027737800495679084
# 5. ContA_PFCd_2_LH: -0.0023622735692161037
# 6. ContA_PFCl_1_LH: -0.0026900838792577367
# 7. ContA_PFCl_2_LH: -0.013674041787379678
# 8. ContA_PFCl_2_RH: -0.0021372503603909083
# 9. ContA_PFCl_5_RH: 0.0073968386659943415
# 10. ContA_PFCl_6_LH: 0.007412060761191459
# 11. ContB_IPL_3_LH: 0.06324678035097488
# 12. ContB_IPL_3_RH: -0.0034833288415379257
# 13. ContB_PFCd_1_LH: -0.013007305294632452
# 14. ContB_PFCl_1_LH: -0.0440648254769156
# 15. ContB_PFCld_2_RH: 0.030804474642995485
# 16. ContB_PFCld_3_RH: -0.0016357845650308745
# 17. ContB_PFCld_4_RH: 0.08252593407642729
# 18. ContB_PFCld_5_RH: 0.020437013329042127
# 19. ContB_PFCld_6_RH: 0.05964594807508769
# 20. DefaultB_IPL_3_LH: 0.008323994190109766
# 21. DefaultB_PFCl_1_LH: -0.0649627774257132
# 22. DefaultB_PFCl_2_LH: -0.007841828573612803
# 23. DefaultB_Temp_2_RH: 0.0
# 24. DefaultB_Temp_5_LH: 0.0
# 25. DorsAttnA_SPL_7_RH: -0.0003186937933458804
# 26. DorsAttnB_FEF_1_LH: -0.008950767184601721
# 27. DorsAttnB_FEF_1_RH: -0.0034236608278881385
# 28. DorsAttnB_FEF_2_RH: 0.006069453119201282
# 29. DorsAttnB_FEF_4_LH: -0.002134058618781781
# 30. DorsAttnB_FEF_4_RH: 0.003637785159808773
# 31. DorsAttnB_PostC_1_LH: -0.003948769730462533
# 32. DorsAttnB_PostC_1_RH: 0.010503662339538934
# 33. DorsAttnB_PostC_2_RH: 0.007057340179459537
# 34. DorsAttnB_PostC_3_LH: 0.05413867926106358
# 35. DorsAttnB_PostC_3_RH: 0.004294968968490532
# 36. DorsAttnB_PostC_4_RH: 0.006271268218479003
# 37. DorsAttnB_PrCv_1_LH: -0.007991433892655737
# 38. DorsAttnB_PrCv_1_RH: 8.355820766421452e-05
# 39. SalVentAttnA_FrOper_3_LH: 0.0
# 40. SalVentAttnA_FrOper_3_RH: 0.0
# 41. SalVentAttnA_FrOper_5_RH: -0.0014200826727697863
# 42. SalVentAttnA_ParOper_1_RH: 0.015039868275925468
# 43. SalVentAttnA_ParOper_2_LH: 0.020654857356361474
# 44. SalVentAttnA_ParOper_3_LH: -0.010755326833522738
# 45. SalVentAttnA_ParOper_3_RH: 0.0066972217402058365
# 46. SalVentAttnA_ParOper_4_RH: 0.004794831168212815
# 47. SalVentAttnA_ParOper_5_LH: 0.01800304668725397
# 48. SalVentAttnA_ParOper_5_RH: 0.002335030823267093
# 49. SalVentAttnA_PrC_1_RH: -0.005144195508634814
# 50. SalVentAttnB_IPL_1_RH: -0.009800297995956005
# 51. SalVentAttnB_IPL_2_RH: -0.0019559942810680768
# 52. SalVentAttnB_Ins_4_RH: -0.0003369756818261953
# 53. SalVentAttnB_PFCd_1_RH: 0.018241323996666378
# 54. SomMotA_10_LH: -0.009998499333181591
# 55. SomMotA_10_RH: -0.003959583654274818
# 56. SomMotA_11_RH: -0.018766358657147073
# 57. SomMotA_12_RH: -0.008460156802381064
# 58. SomMotA_13_RH: -0.02368907099244791
# 59. SomMotA_14_LH: -0.003795234221768938
# 60. SomMotA_14_RH: 0.005432724471346852
# 61. SomMotA_16_LH: -0.00042880441933858504
# 62. SomMotA_17_RH: -0.06947372781955775
# 63. SomMotA_18_RH: -0.047767945630183245
# 64. SomMotA_1_LH: 0.034316811816845406
# 65. SomMotA_1_RH: 0.002472906668708196
# 66. SomMotA_2_RH: 0.0004909938929994411
# 67. SomMotA_3_LH: -0.004159829892611334
# 68. SomMotA_3_RH: 3.895106754416816e-05
# 69. SomMotA_4_LH: 0.10509163187970207
# 70. SomMotA_4_RH: 0.003285291259596816
# 71. SomMotA_5_LH: -0.015906313896019618
# 72. SomMotA_6_RH: 0.004306806672873861
# 73. SomMotA_7_LH: -0.008677109002930849
# 74. SomMotA_7_RH: 0.00751826690129985
# 75. SomMotA_8_RH: -0.004871513489583467
# 76. SomMotA_9_LH: 0.018631884942189987
# 77. SomMotB_Aud_1_LH: 0.0
# 78. SomMotB_Aud_1_RH: 0.0
# 79. SomMotB_Aud_2_LH: 0.0
# 80. SomMotB_Aud_2_RH: 0.0
# 81. SomMotB_Aud_4_LH: -0.013769468956307054
# 82. SomMotB_Aud_4_RH: 0.006935045868758168
# 83. SomMotB_Aud_6_LH: -0.031634291655035056
# 84. SomMotB_Cent_1_LH: -0.0005046396669071117
# 85. SomMotB_Cent_1_RH: -0.0019446914648384582
# 86. SomMotB_Cent_2_LH: -0.017846208140625174
# 87. SomMotB_Cent_2_RH: 6.233591034743547e-05
# 88. SomMotB_Cent_3_LH: 9.904185566850812e-05
# 89. SomMotB_Cent_3_RH: -0.001858512755252035
# 90. SomMotB_Cent_4_LH: 0.003011540084723108
# 91. SomMotB_Cent_4_RH: 0.0019185851888126782
# 92. SomMotB_Cent_5_LH: 0.0028098971591887165
# 93. SomMotB_Cent_5_RH: 0.0015342825918042864
# 94. SomMotB_Cent_6_LH: 0.0017008933204297862
# 95. SomMotB_Cent_7_LH: 0.0013120902792791822
# 96. SomMotB_S2_5_LH: 0.0
# 97. SomMotB_S2_6_LH: 0.0
# 98. SomMotB_S2_6_RH: 0.0
# 99. SomMotB_S2_8_LH: 0.0
# 100. SomMotB_S2_8_RH: 0.00132989638235462
# 101. TempPar_11_RH: 0.006499613514848039
# 102. TempPar_12_RH: 0.001476708293245331
# 103. TempPar_1_LH: 0.0
# 104. TempPar_2_LH: 0.0
# 105. TempPar_3_LH: 0.0
# 106. TempPar_5_LH: -0.00660471262057911
# 107. TempPar_6_RH: 0.001035729630839332
# 108. TempPar_8_LH: -0.020259245082946135

# %%
for i, parcel in enumerate(padded_timeseries.parcel.values.tolist()):
    # get the HbO value at time=0 for this parcel
    v = padded_timeseries.sel(parcel=parcel, chromo='HbO').values[0]
    # make a scalar from array-like results
    try:
        v0 = np.asarray(v).item()
    except Exception:
        v0 = np.asarray(v).ravel()[0]
    # if value is not (close to) zero, print 'keep', otherwise print the numeric value
    display = '-----keep-----' if not np.isclose(v0, 0) else v0
    print(f"{i}. {parcel}: {display}")
# Out:
# 0. ContA_IPS_2_LH: -----keep-----
# 1. ContA_IPS_2_RH: -----keep-----
# 2. ContA_IPS_3_LH: -----keep-----
# 3. ContA_IPS_3_RH: -----keep-----
# 4. ContA_PFCd_1_LH: -----keep-----
# 5. ContA_PFCd_2_LH: -----keep-----
# 6. ContA_PFCl_1_LH: -----keep-----
# 7. ContA_PFCl_2_LH: -----keep-----
# 8. ContA_PFCl_2_RH: -----keep-----
# 9. ContA_PFCl_5_RH: -----keep-----
# 10. ContA_PFCl_6_LH: -----keep-----
# 11. ContB_IPL_3_LH: -----keep-----
# 12. ContB_IPL_3_RH: -----keep-----
# 13. ContB_PFCd_1_LH: -----keep-----
# 14. ContB_PFCl_1_LH: -----keep-----
# 15. ContB_PFCld_2_RH: -----keep-----
# 16. ContB_PFCld_3_RH: -----keep-----
# 17. ContB_PFCld_4_RH: -----keep-----
# 18. ContB_PFCld_5_RH: -----keep-----
# 19. ContB_PFCld_6_RH: -----keep-----
# 20. DefaultB_IPL_3_LH: -----keep-----
# 21. DefaultB_PFCl_1_LH: -----keep-----
# 22. DefaultB_PFCl_2_LH: -----keep-----
# 23. DefaultB_Temp_2_RH: 0.0
# 24. DefaultB_Temp_5_LH: 0.0
# 25. DorsAttnA_SPL_7_RH: -----keep-----
# 26. DorsAttnB_FEF_1_LH: -----keep-----
# 27. DorsAttnB_FEF_1_RH: -----keep-----
# 28. DorsAttnB_FEF_2_RH: -----keep-----
# 29. DorsAttnB_FEF_4_LH: -----keep-----
# 30. DorsAttnB_FEF_4_RH: -----keep-----
# 31. DorsAttnB_PostC_1_LH: -----keep-----
# 32. DorsAttnB_PostC_1_RH: -----keep-----
# 33. DorsAttnB_PostC_2_RH: -----keep-----
# 34. DorsAttnB_PostC_3_LH: -----keep-----
# 35. DorsAttnB_PostC_3_RH: -----keep-----
# 36. DorsAttnB_PostC_4_RH: -----keep-----
# 37. DorsAttnB_PrCv_1_LH: -----keep-----
# 38. DorsAttnB_PrCv_1_RH: -----keep-----
# 39. SalVentAttnA_FrOper_3_LH: 0.0
# 40. SalVentAttnA_FrOper_3_RH: 0.0
# 41. SalVentAttnA_FrOper_5_RH: -----keep-----
# 42. SalVentAttnA_ParOper_1_RH: -----keep-----
# 43. SalVentAttnA_ParOper_2_LH: -----keep-----
# 44. SalVentAttnA_ParOper_3_LH: -----keep-----
# 45. SalVentAttnA_ParOper_3_RH: -----keep-----
# 46. SalVentAttnA_ParOper_4_RH: -----keep-----
# 47. SalVentAttnA_ParOper_5_LH: -----keep-----
# 48. SalVentAttnA_ParOper_5_RH: -----keep-----
# 49. SalVentAttnA_PrC_1_RH: -----keep-----
# 50. SalVentAttnB_IPL_1_RH: -----keep-----
# 51. SalVentAttnB_IPL_2_RH: -----keep-----
# 52. SalVentAttnB_Ins_4_RH: -----keep-----
# 53. SalVentAttnB_PFCd_1_RH: -----keep-----
# 54. SomMotA_10_LH: -----keep-----
# 55. SomMotA_10_RH: -----keep-----
# 56. SomMotA_11_RH: -----keep-----
# 57. SomMotA_12_RH: -----keep-----
# 58. SomMotA_13_RH: -----keep-----
# 59. SomMotA_14_LH: -----keep-----
# 60. SomMotA_14_RH: -----keep-----
# 61. SomMotA_16_LH: -----keep-----
# 62. SomMotA_17_RH: -----keep-----
# 63. SomMotA_18_RH: -----keep-----
# 64. SomMotA_1_LH: -----keep-----
# 65. SomMotA_1_RH: -----keep-----
# 66. SomMotA_2_RH: -----keep-----
# 67. SomMotA_3_LH: -----keep-----
# 68. SomMotA_3_RH: -----keep-----
# 69. SomMotA_4_LH: -----keep-----
# 70. SomMotA_4_RH: -----keep-----
# 71. SomMotA_5_LH: -----keep-----
# 72. SomMotA_6_RH: -----keep-----
# 73. SomMotA_7_LH: -----keep-----
# 74. SomMotA_7_RH: -----keep-----
# 75. SomMotA_8_RH: -----keep-----
# 76. SomMotA_9_LH: -----keep-----
# 77. SomMotB_Aud_1_LH: 0.0
# 78. SomMotB_Aud_1_RH: 0.0
# 79. SomMotB_Aud_2_LH: 0.0
# 80. SomMotB_Aud_2_RH: 0.0
# 81. SomMotB_Aud_4_LH: -----keep-----
# 82. SomMotB_Aud_4_RH: -----keep-----
# 83. SomMotB_Aud_6_LH: -----keep-----
# 84. SomMotB_Cent_1_LH: -----keep-----
# 85. SomMotB_Cent_1_RH: -----keep-----
# 86. SomMotB_Cent_2_LH: -----keep-----
# 87. SomMotB_Cent_2_RH: -----keep-----
# 88. SomMotB_Cent_3_LH: -----keep-----
# 89. SomMotB_Cent_3_RH: -----keep-----
# 90. SomMotB_Cent_4_LH: -----keep-----
# 91. SomMotB_Cent_4_RH: -----keep-----
# 92. SomMotB_Cent_5_LH: -----keep-----
# 93. SomMotB_Cent_5_RH: -----keep-----
# 94. SomMotB_Cent_6_LH: -----keep-----
# 95. SomMotB_Cent_7_LH: -----keep-----
# 96. SomMotB_S2_5_LH: 0.0
# 97. SomMotB_S2_6_LH: 0.0
# 98. SomMotB_S2_6_RH: 0.0
# 99. SomMotB_S2_8_LH: 0.0
# 100. SomMotB_S2_8_RH: -----keep-----
# 101. TempPar_11_RH: -----keep-----
# 102. TempPar_12_RH: -----keep-----
# 103. TempPar_1_LH: 0.0
# 104. TempPar_2_LH: 0.0
# 105. TempPar_3_LH: 0.0
# 106. TempPar_5_LH: -----keep-----
# 107. TempPar_6_RH: -----keep-----
# 108. TempPar_8_LH: -----keep-----

# %%
freqs = [0.5, 0.7, 1.0] 

delta = 2.5
n_shifts = 9


if DATASET_NAME == "BallSqueezingHD_modified":
    shifts = np.linspace(-delta, delta, n_shifts)
elif DATASET_NAME == "FreshMotor":
    shifts = np.linspace(-delta, 0, n_shifts)

print(shifts)
print(np.diff(shifts))
print(np.diff(shifts)*data_pickle['fs'])

# For BSQ-HD where the trial length is 5s, we shift the segments 9 times around the stimulus onset by [-2.5, 2.5] (Difference between the start of the shifted segements is 0.625s)
# Now for FreshMotor where trial duration is 2s, we want to use shift by [2.5, 0]. Does that mean that we still want fix the same number of shifts to 9 (more overlap between segments) as in BSQ-HD dataset wich leads to xxx?
# or we want to fix the same distance between the windows we to to stay as 0.625s which means we shift the signal 4 times only?

# Since the duration of the signals we are interested in is short, the first option makes more sense to me.
# Out:
# [-2.5    -2.1875 -1.875  -1.5625 -1.25   -0.9375 -0.625  -0.3125  0.    ]
# [0.3125 0.3125 0.3125 0.3125 0.3125 0.3125 0.3125 0.3125]
# [2.8125 2.8125 2.8125 2.8125 2.8125 2.8125 2.8125 2.8125]

# %% [markdown]
# # Plot row signal

# %%
subject_idx = 0
with open(pkl_files[subject_idx], 'rb') as handle:
    data_pickle = pickle.load(handle)

timeseries = data_pickle['signal_raw']
dropped_parcels = data_pickle['dropped_parcels']
sensitive_parcels = data_pickle['sensitive_parcels']
len(sensitive_parcels), len(dropped_parcels), timeseries.shape


def _to_numpy(value):
    if hasattr(value, 'to_numpy'):
        return value.to_numpy()
    return np.asarray(value)

# -------------------------------------------------------------
# Raw HbO + HbR parcel signals (true amplitude)
# Subplots touching, individual Y-axis scales, transparent frame
# -------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

NUM_PARCELS_TO_PLOT = min(10, len(sensitive_parcels))

def _to_numpy(value):
    if hasattr(value, 'to_numpy'):
        return value.to_numpy()
    return np.asarray(value)

stim = data_pickle['stim']
stim_onsets = _to_numpy(stim['onset'])
stim_labels = _to_numpy(stim['trial_type'])
stim_durations = _to_numpy(stim['duration'])

# -------------------------------------------------------------
# Preprocessing
# -------------------------------------------------------------
signal_raw = data_pickle['signal_raw']

signal = cedalion.sigproc.frequency.freq_filter(
    signal_raw,
    0.008 * units.Hz,
    FMAX * units.Hz,
    4
)

# timeseries, _ = cedalion.sigproc.physio.global_component_subtract(
#     ts=signal, k=0, spatial_dim='parcel', spectral_dim='chromo'
# )

# NOTE: raw amplitude (no normalization)
timeseries = timeseries.sel(parcel=sensitive_parcels).reindex(parcel=PARCEL_TEMPLATE, fill_value=0)



for i, parcel in enumerate(timeseries.parcel.values.tolist()):
    v = timeseries.sel(parcel=parcel, chromo='HbO').values[0]
    try:
        v0 = np.asarray(v).item()
    except Exception:
        v0 = np.asarray(v).ravel()[0]
    # display = 'KEEP' if not np.isclose(v0, 0) else v0
    display = '--- KEEP ---' if not v0 == 0 else v0
    
    print(f"{i}. {parcel}: {display}")
    
    
    
    
parcel_subset = PARCEL_TEMPLATE[:NUM_PARCELS_TO_PLOT]

# Time axis
try:
    time_axis = timeseries.time.as_numpy()
except:
    time_axis = np.arange(timeseries.shape[-1])

# -------------------------------------------------------------
# Subplots with INDIVIDUAL y-axis scales per parcel
# -------------------------------------------------------------
fig, axes = plt.subplots(
    NUM_PARCELS_TO_PLOT,
    1,
    figsize=(16, 12),
    sharex=True,
    sharey=False        # <<< IMPORTANT: disable shared amplitude
)

if NUM_PARCELS_TO_PLOT == 1:
    axes = [axes]

# Touching subplots
plt.subplots_adjust(hspace=0.0)
fig.subplots_adjust(top=0.96, bottom=0.06, left=0.12, right=0.98)

# -------------------------------------------------------------
# Plot each parcel
# -------------------------------------------------------------
colors = {"HbO": "red", "HbR": "blue"}

for ax, parcel in zip(axes, parcel_subset):

    trace_hbo = timeseries.sel(parcel=parcel).isel(chromo=0).as_numpy()
    trace_hbr = timeseries.sel(parcel=parcel).isel(chromo=1).as_numpy()

    # Plot raw signals (no scaling)
    ax.plot(time_axis, trace_hbo, color=colors["HbO"], linewidth=1)
    ax.plot(time_axis, trace_hbr, color=colors["HbR"], linewidth=1)

    # Parcel label
    ax.set_ylabel(
        str(parcel),
        fontsize=8,
        rotation=0,
        labelpad=40,
        ha='right',
        va='center'
    )

    # Stimulus markers
    if stim_onsets.size > 0:
        for onset in stim_onsets:
            ax.axvline(onset, color='black', linestyle='--', alpha=0.5)
    if stim_onsets.size > 0 and stim_durations.size > 0:
        for onset, duration in zip(stim_onsets, stim_durations):
            ax.axvspan(onset, onset + duration, color='gray', alpha=0.1)

    # *** INDIVIDUAL local y-axis ***
    local_min = min(trace_hbo.min(), trace_hbr.min())
    local_max = max(trace_hbo.max(), trace_hbr.max())
    ax.set_ylim(local_min, local_max)

    ax.grid(alpha=0.3)
    ax.xaxis.set_major_locator(MaxNLocator(10))

    # Transparent frame (remove axis box)
    for spine in ax.spines.values():
        spine.set_visible(False)

# Bottom subplot gets x-label only
axes[-1].set_xlabel("Time (s)")

# Legend appears once
axes[0].legend(['HbO', 'HbR'], loc='upper right')

fig.suptitle(
    f"Full Timeseries - {pkl_files[subject_idx].split('/')[-1].split('.')[0].replace('_', ' ').replace('nirs ts all parcels', '')}",
    fontsize=14
)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig(PROCESSED_DIR / f'full_timeseries_individual_yaxis_{DATASET_NAME}_{pkl_files[subject_idx].split("/")[-1].split(".")[0]}.png', dpi=300)
plt.show()
# Out:
# 0. ContA_IPS_2_LH: --- KEEP ---
# 1. ContA_IPS_2_RH: --- KEEP ---
# 2. ContA_IPS_3_LH: --- KEEP ---
# 3. ContA_IPS_3_RH: --- KEEP ---
# 4. ContA_PFCd_1_LH: --- KEEP ---
# 5. ContA_PFCd_2_LH: --- KEEP ---
# 6. ContA_PFCl_1_LH: --- KEEP ---
# 7. ContA_PFCl_2_LH: --- KEEP ---
# 8. ContA_PFCl_2_RH: --- KEEP ---
# 9. ContA_PFCl_5_RH: --- KEEP ---
# 10. ContA_PFCl_6_LH: --- KEEP ---
# 11. ContB_IPL_3_LH: --- KEEP ---
# 12. ContB_IPL_3_RH: --- KEEP ---
# 13. ContB_PFCd_1_LH: --- KEEP ---
# 14. ContB_PFCl_1_LH: --- KEEP ---
# 15. ContB_PFCld_2_RH: --- KEEP ---
# 16. ContB_PFCld_3_RH: --- KEEP ---
# 17. ContB_PFCld_4_RH: --- KEEP ---
# 18. ContB_PFCld_5_RH: --- KEEP ---
# 19. ContB_PFCld_6_RH: --- KEEP ---
# 20. DefaultB_IPL_3_LH: --- KEEP ---
# 21. DefaultB_PFCl_1_LH: --- KEEP ---
# 22. DefaultB_PFCl_2_LH: --- KEEP ---
# 23. DefaultB_Temp_2_RH: 0.0
# 24. DefaultB_Temp_5_LH: 0.0
# 25. DorsAttnA_SPL_7_RH: --- KEEP ---
# 26. DorsAttnB_FEF_1_LH: --- KEEP ---
# 27. DorsAttnB_FEF_1_RH: --- KEEP ---
# 28. DorsAttnB_FEF_2_RH: --- KEEP ---
# 29. DorsAttnB_FEF_4_LH: --- KEEP ---
# 30. DorsAttnB_FEF_4_RH: --- KEEP ---
# 31. DorsAttnB_PostC_1_LH: --- KEEP ---
# 32. DorsAttnB_PostC_1_RH: 0.0
# 33. DorsAttnB_PostC_2_RH: --- KEEP ---
# 34. DorsAttnB_PostC_3_LH: --- KEEP ---
# 35. DorsAttnB_PostC_3_RH: --- KEEP ---
# 36. DorsAttnB_PostC_4_RH: --- KEEP ---
# 37. DorsAttnB_PrCv_1_LH: --- KEEP ---
# 38. DorsAttnB_PrCv_1_RH: --- KEEP ---
# 39. SalVentAttnA_FrOper_3_LH: 0.0
# 40. SalVentAttnA_FrOper_3_RH: 0.0
# 41. SalVentAttnA_FrOper_5_RH: --- KEEP ---
# 42. SalVentAttnA_ParOper_1_RH: --- KEEP ---
# 43. SalVentAttnA_ParOper_2_LH: --- KEEP ---
# 44. SalVentAttnA_ParOper_3_LH: 0.0
# 45. SalVentAttnA_ParOper_3_RH: 0.0
# 46. SalVentAttnA_ParOper_4_RH: --- KEEP ---
# 47. SalVentAttnA_ParOper_5_LH: --- KEEP ---
# 48. SalVentAttnA_ParOper_5_RH: --- KEEP ---
# 49. SalVentAttnA_PrC_1_RH: --- KEEP ---
# 50. SalVentAttnB_IPL_1_RH: --- KEEP ---
# 51. SalVentAttnB_IPL_2_RH: --- KEEP ---
# 52. SalVentAttnB_Ins_4_RH: --- KEEP ---
# 53. SalVentAttnB_PFCd_1_RH: --- KEEP ---
# 54. SomMotA_10_LH: --- KEEP ---
# 55. SomMotA_10_RH: --- KEEP ---
# 56. SomMotA_11_RH: --- KEEP ---
# 57. SomMotA_12_RH: --- KEEP ---
# 58. SomMotA_13_RH: --- KEEP ---
# 59. SomMotA_14_LH: --- KEEP ---
# 60. SomMotA_14_RH: --- KEEP ---
# 61. SomMotA_16_LH: --- KEEP ---
# 62. SomMotA_17_RH: --- KEEP ---
# 63. SomMotA_18_RH: --- KEEP ---
# 64. SomMotA_1_LH: --- KEEP ---
# 65. SomMotA_1_RH: --- KEEP ---
# 66. SomMotA_2_RH: --- KEEP ---
# 67. SomMotA_3_LH: --- KEEP ---
# 68. SomMotA_3_RH: --- KEEP ---
# 69. SomMotA_4_LH: --- KEEP ---
# 70. SomMotA_4_RH: --- KEEP ---
# 71. SomMotA_5_LH: --- KEEP ---
# 72. SomMotA_6_RH: --- KEEP ---
# 73. SomMotA_7_LH: --- KEEP ---
# 74. SomMotA_7_RH: --- KEEP ---
# 75. SomMotA_8_RH: --- KEEP ---
# 76. SomMotA_9_LH: --- KEEP ---
# 77. SomMotB_Aud_1_LH: 0.0
# 78. SomMotB_Aud_1_RH: 0.0
# 79. SomMotB_Aud_2_LH: 0.0
# 80. SomMotB_Aud_2_RH: 0.0
# 81. SomMotB_Aud_4_LH: 0.0
# 82. SomMotB_Aud_4_RH: 0.0
# 83. SomMotB_Aud_6_LH: --- KEEP ---
# 84. SomMotB_Cent_1_LH: --- KEEP ---
# 85. SomMotB_Cent_1_RH: --- KEEP ---
# 86. SomMotB_Cent_2_LH: --- KEEP ---
# 87. SomMotB_Cent_2_RH: --- KEEP ---
# 88. SomMotB_Cent_3_LH: --- KEEP ---
# 89. SomMotB_Cent_3_RH: --- KEEP ---
# 90. SomMotB_Cent_4_LH: --- KEEP ---
# 91. SomMotB_Cent_4_RH: --- KEEP ---
# 92. SomMotB_Cent_5_LH: --- KEEP ---
# 93. SomMotB_Cent_5_RH: --- KEEP ---
# 94. SomMotB_Cent_6_LH: --- KEEP ---
# 95. SomMotB_Cent_7_LH: --- KEEP ---
# 96. SomMotB_S2_5_LH: 0.0
# 97. SomMotB_S2_6_LH: 0.0
# 98. SomMotB_S2_6_RH: 0.0
# 99. SomMotB_S2_8_LH: 0.0
# 100. SomMotB_S2_8_RH: 0.0
# 101. TempPar_11_RH: 0.0
# 102. TempPar_12_RH: --- KEEP ---
# 103. TempPar_1_LH: 0.0
# 104. TempPar_2_LH: 0.0
# 105. TempPar_3_LH: 0.0
# 106. TempPar_5_LH: 0.0
# 107. TempPar_6_RH: 0.0
# 108. TempPar_8_LH: --- KEEP ---

# %% [markdown]
# # Create segmentation

# %%
# segment_sh_conc_pcr[:, :, :TIME_SEGMENT].shape # (2, 68, 90) <- freshmotor
# segment_sh_conc_pcr[:, :, :TIME_SEGMENT].shape # (2, 100, 90) <- BSQ-HD

# %%
INDEX = 0
for FMAX in freqs:
    print(f'Processing frequency: {FMAX} Hz')
    freq_dir = PROCESSED_DIR / f'frq{FMAX}'
    freq_dir.mkdir(exist_ok=True)
    
    subject_to_rec = {}
    for file in pkl_files:
        print(f'Processing file: {file}')
        with open(file, 'rb') as handle:
            data_pickle = pickle.load(handle)
            
        signal_raw = data_pickle['signal_raw']
        conc_pcr_raw = data_pickle['conc_pcr']
        dropped_parcels = data_pickle['dropped_parcels']
        sensitive_parcels = data_pickle['sensitive_parcels']
        stim = data_pickle['stim']
        label = data_pickle['label']
        
        fs = float(data_pickle['fs'])
        TIME_SEGMENT = int(round(fs * stim['duration'][0])) # assuming all trials in the session have the same duration

        # bandpass filter
        # 
        signal = cedalion.sigproc.frequency.freq_filter(
            signal_raw,
            0.01 * units.Hz,
            FMAX * units.Hz,
            4
        )
        
        conc_pcr = cedalion.sigproc.frequency.freq_filter(
            conc_pcr_raw,
            0.01 * units.Hz,
            FMAX * units.Hz,
            4
        )

        # phy-removal within the parcel-dimension
        # timeseries, _ = cedalion.sigproc.physio.global_component_subtract(ts=signal, k=0 ,spatial_dim='parcel',spectral_dim='chromo')
        
        # normalize
        timeseries, norm_factor = max_value_normalize(signal)
        timeseries_conc_pcr, norm_factor_conc_pcr = max_value_normalize(conc_pcr)
        
        # Pad timeseries to have consistent parcel dimension
        timeseries = timeseries.sel(parcel=sensitive_parcels).reindex(parcel=PARCEL_TEMPLATE, fill_value=0)

        # extract meta information
        data = timeseries.as_numpy()
        data_conc_pcr = timeseries_conc_pcr.as_numpy()
        
        time = timeseries.time.as_numpy()

        reference = np.zeros(time.shape[0])
        SUB = PureWindowsPath(file).parts[-2]
        if SUB not in subject_to_rec:
            subject_to_rec[SUB] = []
        try:
            sub_dir = Path(freq_dir) / SUB
            sub_dir.mkdir(parents=True, exist_ok=True)
        except FileExistsError:
            pass
        
        # create segments
        for onset, du, ty in zip(stim['onset'], stim['duration'], stim['trial_type']):

            # update the reference with correct labels
            onset_idx = int(round(onset * fs))
            duration_samples = int(round(du * fs))
            reference[onset_idx:onset_idx + duration_samples] = label[ty]
            
            mylist = []
            # shift the data to generate more samples
            for delta_ in shifts:
                shift_samples = int(round(delta_ * fs))
                start_idx = onset_idx + shift_samples
                end_idx = start_idx + TIME_SEGMENT
                if start_idx < 0 or end_idx > data.shape[-1]:
                    continue
                segment_sh = data[:, :, start_idx:end_idx]
                segment_sh_conc_pcr = data_conc_pcr[:, :, start_idx:end_idx]
                
                ref_segment = reference[start_idx:end_idx]

                # save files
                filename = r'{}/{}/event_{}_delta{:+.2f}_{}.pkl'.format(freq_dir, SUB, 'aug' if delta_ != 0.0 else 'orig', delta_, INDEX)
                subject_to_rec[SUB].append(filename)
                INDEX += 1
                print(filename)
                
                # dataset information            
                segment_data = {
                    'xt': segment_sh[:, :, :TIME_SEGMENT],
                    'xt_conc_pcr': segment_sh_conc_pcr[:, :, :TIME_SEGMENT],
                    'ref': ref_segment[:TIME_SEGMENT],
                    'class': label[ty],
                    'file': file,
                    'norm_factor': float(norm_factor),
                    'norm_factor_conc_pcr': float(norm_factor_conc_pcr),
                    'parcel_template': PARCEL_TEMPLATE,
                    'TIME_SEGMENT': TIME_SEGMENT
                }
                mylist.append(segment_data)

                with open(filename, 'wb') as handle:
                    pickle.dump(segment_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

    with open('{}/meta_event_{}.pkl'.format(freq_dir, FMAX), 'wb') as handle:
        pickle.dump(subject_to_rec, handle, protocol=pickle.HIGHEST_PROTOCOL)

print('Done!')
# Out:
# Processing frequency: 0.5 Hz
# Processing file: datasets/preprocessed/FreshMotor/ts_all_parcels/sub-08/sub-08_task-FRESHMOTOR_run-left2s_nirs_ts_all_parcels.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_0.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_1.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_2.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_3.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_4.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_5.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_6.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_7.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_8.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_9.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_10.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_11.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_12.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_13.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_14.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_15.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_16.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_17.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_18.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_19.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_20.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_21.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_22.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_23.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_24.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_25.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_26.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_27.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_28.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_29.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_30.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_31.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_32.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_33.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_34.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_35.pkl
# /opt/conda/envs/cedalion/lib/python3.11/site-packages/xarray/core/variable.py:315: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   data = np.asarray(data)
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_36.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_37.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_38.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_39.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_40.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_41.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_42.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_43.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_44.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_45.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_46.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_47.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_48.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_49.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_50.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_51.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_52.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_53.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_54.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_55.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_56.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_57.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_58.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_59.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_60.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_61.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_62.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_63.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_64.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_65.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_66.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_67.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_68.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_69.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_70.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_71.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_72.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_73.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_74.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_75.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_76.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_77.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_78.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_79.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_80.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_81.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_82.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_83.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_84.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_85.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_86.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_87.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_88.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_89.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_90.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_91.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_92.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_93.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_94.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_95.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_96.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_97.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_98.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_99.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_100.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_101.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_102.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_103.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_104.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_105.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_106.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_107.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_108.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_109.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_110.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_111.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_112.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_113.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_114.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_115.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_116.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_117.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_118.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_119.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_120.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_121.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_122.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_123.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_124.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_125.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_126.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_127.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_128.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_129.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_130.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_131.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_132.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_133.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_134.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_135.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_136.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_137.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_138.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_139.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_140.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_141.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_142.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_143.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_144.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_145.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_146.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_147.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_148.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_149.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_150.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_151.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_152.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_153.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_154.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_155.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_156.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_157.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_158.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_159.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_160.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_161.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_162.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_163.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_164.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_165.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_166.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_167.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_168.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_169.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_170.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_171.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_172.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_173.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_174.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_175.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_176.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_177.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_178.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_179.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_180.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_181.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_182.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_183.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_184.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_185.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_186.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_187.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_188.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_189.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_190.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_191.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_192.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_193.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_194.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_195.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_196.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_197.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_198.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_199.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_200.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_201.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_202.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_203.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_204.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_205.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_206.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_207.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_208.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_209.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_210.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_211.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_212.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_213.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_214.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_215.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_216.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_217.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_218.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_219.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_220.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_221.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_222.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_223.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_224.pkl
# Processing file: datasets/preprocessed/FreshMotor/ts_all_parcels/sub-08/sub-08_task-FRESHMOTOR_run-right2s_nirs_ts_all_parcels.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_225.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_226.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_227.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_228.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_229.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_230.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_231.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_232.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_233.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_234.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_235.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_236.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_237.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_238.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_239.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_240.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_241.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_242.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_243.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_244.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_245.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_246.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_247.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_248.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_249.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_250.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_251.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_252.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_253.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_254.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_255.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_256.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_257.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_258.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_259.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_260.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_261.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_262.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_263.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_264.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_265.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_266.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_267.pkl
# /opt/conda/envs/cedalion/lib/python3.11/site-packages/xarray/core/variable.py:315: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   data = np.asarray(data)
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_268.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_269.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_270.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_271.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_272.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_273.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_274.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_275.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_276.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_277.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_278.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_279.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_280.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_281.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_282.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_283.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_284.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_285.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_286.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_287.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_288.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_289.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_290.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_291.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_292.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_293.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_294.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_295.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_296.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_297.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_298.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_299.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_300.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_301.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_302.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_303.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_304.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_305.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_306.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_307.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_308.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_309.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_310.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_311.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_312.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_313.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_314.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_315.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_316.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_317.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_318.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_319.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_320.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_321.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_322.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_323.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_324.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_325.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_326.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_327.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_328.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_329.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_330.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_331.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_332.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_333.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_334.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_335.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_336.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_337.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_338.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_339.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_340.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_341.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_342.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_343.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_344.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_345.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_346.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_347.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_348.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_349.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_350.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_351.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_352.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_353.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_354.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_355.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_356.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_357.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_358.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_359.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_360.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_361.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_362.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_363.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_364.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_365.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_366.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_367.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_368.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_369.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_370.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_371.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_372.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_373.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_374.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_375.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_376.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_377.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_378.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_379.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_380.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_381.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_382.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_383.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_384.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_385.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_386.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_387.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_388.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_389.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_390.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_391.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_392.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_393.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_394.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_395.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_396.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_397.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_398.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_399.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_400.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_401.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_402.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_403.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_404.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_405.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_406.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_407.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_408.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_409.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_410.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_411.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_412.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_413.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_414.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_415.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_416.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_417.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_418.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_419.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_420.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_421.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_422.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_423.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_424.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_425.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_426.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_427.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_428.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_429.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_430.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_431.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_432.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_433.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_434.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_435.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_436.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_437.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_438.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_439.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_440.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_441.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_442.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_443.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_444.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_445.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_446.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_447.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_448.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_449.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_450.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_451.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_452.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_453.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_454.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_455.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_456.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_457.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_458.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_459.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_460.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_461.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_462.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_463.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_464.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_465.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_466.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_467.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_468.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_469.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_470.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_471.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_472.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_473.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_474.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_475.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_476.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_477.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_478.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_479.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_480.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_481.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_482.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_483.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_484.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_485.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_486.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_487.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_488.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_489.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_490.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_491.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_492.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_493.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_494.pkl
# Processing file: datasets/preprocessed/FreshMotor/ts_all_parcels/sub-08/sub-08_task-FRESHMOTOR_run-left3s_nirs_ts_all_parcels.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_495.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_496.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_497.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_498.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_499.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_500.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_501.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_502.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_503.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_504.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_505.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_506.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_507.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_508.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_509.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_510.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_511.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_512.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_513.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_514.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_515.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_516.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_517.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_518.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_519.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_520.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_521.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_522.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_523.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_524.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_525.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_526.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_527.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_528.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_529.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_530.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_531.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_532.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_533.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_534.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_535.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_536.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_537.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_538.pkl
# /opt/conda/envs/cedalion/lib/python3.11/site-packages/xarray/core/variable.py:315: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   data = np.asarray(data)
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_539.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_540.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_541.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_542.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_543.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_544.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_545.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_546.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_547.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_548.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_549.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_550.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_551.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_552.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_553.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_554.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_555.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_556.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_557.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_558.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_559.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_560.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_561.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_562.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_563.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_564.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_565.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_566.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_567.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_568.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_569.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_570.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_571.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_572.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_573.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_574.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_575.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_576.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_577.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_578.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_579.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_580.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_581.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_582.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_583.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_584.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_585.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_586.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_587.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_588.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_589.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_590.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_591.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_592.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_593.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_594.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_595.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_596.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_597.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_598.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_599.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_600.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_601.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_602.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_603.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_604.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_605.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_606.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_607.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_608.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_609.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_610.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_611.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_612.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_613.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_614.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_615.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_616.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_617.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_618.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_619.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_620.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_621.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_622.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_623.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_624.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_625.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_626.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_627.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_628.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_629.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_630.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_631.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_632.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_633.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_634.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.94_635.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.62_636.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-0.31_637.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_orig_delta+0.00_638.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.50_639.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-2.19_640.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.88_641.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.56_642.pkl
# datasets/processed/FreshMotor/frq0.5/sub-08/event_aug_delta-1.25_643.pkl
# ...
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29247.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29248.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29249.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29250.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29251.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29252.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29253.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29254.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29255.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29256.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29257.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29258.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29259.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29260.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29261.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29262.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29263.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29264.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29265.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29266.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29267.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29268.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29269.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29270.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29271.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29272.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29273.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29274.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29275.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29276.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29277.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29278.pkl
# /opt/conda/envs/cedalion/lib/python3.11/site-packages/xarray/core/variable.py:315: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   data = np.asarray(data)
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29279.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29280.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29281.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29282.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29283.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29284.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29285.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29286.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29287.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29288.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29289.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29290.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29291.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29292.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29293.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29294.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29295.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29296.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29297.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29298.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29299.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29300.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29301.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29302.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29303.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29304.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29305.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29306.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29307.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29308.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29309.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29310.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29311.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29312.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29313.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29314.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29315.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29316.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29317.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29318.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29319.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29320.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29321.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29322.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29323.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29324.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29325.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29326.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29327.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29328.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29329.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29330.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29331.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29332.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29333.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29334.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29335.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29336.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29337.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29338.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29339.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29340.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29341.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29342.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29343.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29344.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29345.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29346.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29347.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29348.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29349.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29350.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29351.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29352.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29353.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29354.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29355.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29356.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29357.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29358.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29359.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29360.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29361.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29362.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29363.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29364.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29365.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29366.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29367.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29368.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29369.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29370.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29371.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29372.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29373.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29374.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29375.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29376.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29377.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29378.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29379.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29380.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29381.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29382.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29383.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29384.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29385.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29386.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29387.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29388.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29389.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29390.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29391.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29392.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29393.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29394.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29395.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29396.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29397.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29398.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29399.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29400.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29401.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29402.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29403.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29404.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29405.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29406.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29407.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29408.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29409.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29410.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29411.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29412.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29413.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29414.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29415.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29416.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29417.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29418.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29419.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29420.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29421.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29422.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29423.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29424.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29425.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29426.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29427.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29428.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29429.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29430.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29431.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29432.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29433.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29434.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29435.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29436.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29437.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29438.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29439.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29440.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29441.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29442.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29443.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29444.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29445.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29446.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29447.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.50_29448.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-2.19_29449.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.88_29450.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.56_29451.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-1.25_29452.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.94_29453.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.62_29454.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_aug_delta-0.31_29455.pkl
# datasets/processed/FreshMotor/frq1.0/sub-10/event_orig_delta+0.00_29456.pkl
# Done!

# %% [markdown]
# # Save event files

# %%
if recreate_segments:
    events = "datasets/processed/{}/frq{}/meta_event_{}.pkl"
        
    meta_events = []
    for freq in freqs:
        with open(events.format(DATASET_NAME, freq, freq), 'rb') as handle:
            meta = pickle.load(handle)
        meta_events.append(meta)


    if DATASET_NAME == "BallSqueezingHD_modified":
        session_to_files = {'run-1':[],
                            'run-2':[],
                            'run-3':[]}
        
    elif DATASET_NAME == "FreshMotor":    
        session_to_files = {'run-left2s':[],
                            'run-right2s':[],
                            'run-left3s':[],
                            'run-right3s':[]}

    files_to_session = {}
    for meta_event in meta_events:
        for sub in meta_event:
            for file in meta_event[sub]:
                meta = None
                with open(file, 'rb') as handle:
                    meta = pickle.load(handle) 
                run = meta['file'].split('_')[-5]
                files_to_session[file] = run
                session_to_files[run].append(file)

    for run in session_to_files:
        print(run, len(session_to_files[run]))

    # this will save the mapping of files to sessions used for LOSO
    with open(f'datasets/processed/{DATASET_NAME}/files_to_sessions.pkl', 'wb') as handle:
        pickle.dump(files_to_session, handle, protocol=pickle.HIGHEST_PROTOCOL)     
    print("Saved files_to_sessions.pkl")
# Out:
# run-left2s 6669
# run-right2s 8019
# run-left3s 6669
# run-right3s 8100
# Saved files_to_sessions.pkl

# %%
FMAX = 0.5
freq_dir = Path(PROCESSED_DIR / f'frq{FMAX}')
recursive = True

if recursive:
    n = sum(1 for _ in freq_dir.rglob('*.pkl'))
else:
    n = sum(1 for _ in freq_dir.glob('*.pkl'))
print(n)
# Out:
# 9820

# %%
segment_count = sum(1 for _ in freq_dir.rglob('*') if _.is_file())
segment_count
# Out:
# 9820

# %%
# -------------------------------------------------------------
# Inspect a single saved segment and overlay stimulus events
# -------------------------------------------------------------
FMAX = 0.5
subject_id = "sub-10" if DATASET_NAME == "FreshMotor" else "sub-177"
freq_dir = Path(PROCESSED_DIR / f'frq{FMAX}')
if DATASET_NAME == "FreshMotor":
    sample_file = freq_dir / subject_id / 'event_aug_delta-2.50_9666.pkl'
elif DATASET_NAME == "BallSqueezingHD_modified":
    sample_file = freq_dir / subject_id / 'event_aug_delta+0.62_4021.pkl'
import re
from matplotlib.ticker import MultipleLocator
with open(sample_file, 'rb') as handle:
    segment_data = pickle.load(handle)

xt = np.asarray(segment_data['xt'])
ref = np.asarray(segment_data['ref'])
class_label = segment_data['class']
label_map = {
    1: 'right',
    2: 'left'
}
class_name = label_map.get(class_label, str(class_label))
file = segment_data['file']
norm_factor = segment_data['norm_factor']
parcel_template = segment_data['parcel_template']
TIME_SEGMENT = segment_data['TIME_SEGMENT']

with open(file, 'rb') as handle:
    original_data = pickle.load(handle)
fs = float(original_data['fs'])
trial_duration = TIME_SEGMENT / fs

delta_match = re.search(r'delta([+-]?\d+\.\d+)', sample_file.name)
delta_value = float(delta_match.group(1)) if delta_match else 0.0

parcel_idx = 100  # Change this index to plot different parcels
sample_axis = np.arange(TIME_SEGMENT)
time_axis = delta_value + sample_axis / fs

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(time_axis, xt[0, parcel_idx, :], label='HbO', color='red')
ax.plot(time_axis, xt[1, parcel_idx, :], label='HbR', color='blue')

stim_onset = 0.0
stim_offset = trial_duration
ax.axvspan(stim_onset, stim_offset, color='red', alpha=0.1, label='Stimulus window')
ax.axvline(stim_onset, color='red', linestyle='--', alpha=0.7)
ax.text(stim_onset, ax.get_ylim()[1], class_name, color='red', fontsize=8, verticalalignment='bottom')

fig.suptitle(f'Single Segment - {DATASET_NAME} - FMAX: {FMAX} - {subject_id}', fontsize=14),
ax.set_title(f'Parcel: {parcel_template[parcel_idx]}, Class: {class_name}, delta: {delta_value:+.2f} s')

ax.set_xlabel('Time (s)')
ax.set_ylabel('Normalized Amplitude')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5) )
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.grid(True)
pad = abs(delta_value)
ax.set_xlim(-pad, trial_duration + pad)
secax = ax.secondary_xaxis('top', functions=(lambda t: t * fs, lambda s: s / fs))
secax.set_xlabel('Samples from onset')
secax.xaxis.set_major_locator(MultipleLocator(fs))

plt.tight_layout()
plt.savefig(PROCESSED_DIR / f'single_segment_{DATASET_NAME}_{sample_file.stem}_parcel{parcel_idx}.png', dpi=300)
plt.show()

# %%
# -------------------------------------------------------------
# Block-averaged evoked response per class for a given delta
# -------------------------------------------------------------
# FMAX = 0.5
# subject_id = 'sub-02' #'sub-177'
target_delta = -2.5 # seconds
parcel_idx = 1
freq_dir = Path(PROCESSED_DIR / f'frq{FMAX}')
delta_tag = f"delta{target_delta:+.2f}"
segment_files = sorted((freq_dir / subject_id).glob(f'event_*_{delta_tag}_*.pkl'))
if not segment_files:
    raise ValueError(f'No segments found for delta {target_delta} in {subject_id}')

label_map = {1: 'right', 2: 'left'}
segments_by_class = {k: [] for k in label_map}
fs = None
parcel_template = None
TIME_SEGMENT = None
for seg_path in segment_files:
    with open(seg_path, 'rb') as handle:
        seg = pickle.load(handle)
    class_id = seg['class']
    if class_id not in segments_by_class:
        continue
    if fs is None:
        with open(seg['file'], 'rb') as handle:
            orig = pickle.load(handle)
        fs = float(orig['fs'])
        TIME_SEGMENT = seg['TIME_SEGMENT']
        parcel_template = seg['parcel_template']
    segments_by_class[class_id].append(seg['xt'][parcel_idx, :, :])

trial_duration = TIME_SEGMENT / fs
sample_axis = np.arange(TIME_SEGMENT)
fig, ax = plt.subplots(figsize=(12, 5))
pad = abs(target_delta)
for class_id, traces in segments_by_class.items():
    if not traces:
        continue
    traces = np.stack(traces)
    hbO_mean = traces[:, 0, :].mean(axis=0)
    hbR_mean = traces[:, 1, :].mean(axis=0)
    time_axis = target_delta + sample_axis / fs
    if class_id == 1:
        line_style = '--'
    elif class_id == 2:
        line_style = '-'
    else:
        line_style = ':'
    ax.plot(time_axis, hbO_mean, label=f"HbO mean ({label_map[class_id]})", color='red', linestyle=line_style)
    ax.plot(time_axis, hbR_mean, label=f"HbR mean ({label_map[class_id]})", color='blue', linestyle=line_style)

ax.axvspan(0.0, trial_duration, color='red', alpha=0.1, label='Stimulus window')
ax.axvline(0.0, color='red', linestyle='--', alpha=0.7)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Normalized Amplitude')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5) )
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.grid(True)
ax.set_xlim(-pad, trial_duration + pad)
secax = ax.secondary_xaxis('top', functions=(lambda t: t * fs, lambda s: s / fs))
secax.set_xlabel('Samples from onset')
secax.xaxis.set_major_locator(MultipleLocator(fs))
fig.suptitle(f'Block Average (evoked) - {DATASET_NAME} - FMAX: {FMAX} - {subject_id}', fontsize=14)
ax.set_title(f'Parcel: {parcel_template[parcel_idx]}, delta: {target_delta:+.2f} s')
plt.tight_layout()
plt.savefig(PROCESSED_DIR / f'block_average_evoked_{DATASET_NAME}_{subject_id}_parcel{parcel_idx}_{delta_tag}.png', dpi=300)
plt.show()

# %%
# -------------------------------------------------------------
# Grid of parcel-wise block averages for a given delta
# -------------------------------------------------------------
FMAX = 0.5
# subject_id = 'sub-1'  #'sub-177'
target_delta = -2.5  # seconds
# parcel_indices = [0, 5, 10, 15, 20, 25]
parcel_indices = list(range(len(parcel_template)))

n_cols = 10
freq_dir = Path(PROCESSED_DIR / f'frq{FMAX}')
delta_tag = f"delta{target_delta:+.2f}"
segment_files = sorted((freq_dir / subject_id).glob(f'event_*_{delta_tag}_*.pkl'))
if not segment_files:
    raise ValueError(f'No segments found for delta {target_delta} in {subject_id}')

label_map = {0: 'rest', 1: 'right', 2: 'left'}
segments_by_class = {k: [] for k in label_map}
fs = None
parcel_template = None
TIME_SEGMENT = None
for seg_path in segment_files:
    with open(seg_path, 'rb') as handle:
        seg = pickle.load(handle)
    class_id = seg['class']
    if class_id not in segments_by_class:
        continue
    if fs is None:
        with open(seg['file'], 'rb') as handle:
            orig = pickle.load(handle)
        fs = float(orig['fs'])
        TIME_SEGMENT = seg['TIME_SEGMENT']
        parcel_template = seg['parcel_template']
    segments_by_class[class_id].append(seg['xt'])

trial_duration = TIME_SEGMENT / fs
sample_axis = np.arange(TIME_SEGMENT)
time_axis = target_delta + sample_axis / fs
pad = abs(target_delta)
n_rows = int(np.ceil(len(parcel_indices) / n_cols))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3 * n_rows), sharex=True, sharey=True)
fig.suptitle(f'Block Average (evoked) - {DATASET_NAME} - FMAX: {FMAX} - {subject_id} - delta {target_delta:+.2f}s - all parcels', fontsize=26, y=1.03)
axes = axes.flatten()
for ax_idx, ax in enumerate(axes):
    if ax_idx >= len(parcel_indices):
        ax.axis('off')
        continue
    parcel_idx = parcel_indices[ax_idx]
    for class_id, imgs in segments_by_class.items():
        if not imgs:
            continue
        traces = np.stack(imgs)
        hbO_mean = traces[:, 0, parcel_idx, :].mean(axis=0)
        hbR_mean = traces[:, 1, parcel_idx, :].mean(axis=0)
        if class_id == 1:
            line_style = '--'
        elif class_id == 2:
            line_style = '-'
        else:
            line_style = ':'
        ax.plot(time_axis, hbO_mean, color='red', linestyle=line_style, label=f"HbO {label_map[class_id]}", linewidth=2.5)
        ax.plot(time_axis, hbR_mean, color='blue', linestyle=line_style, label=f"HbR {label_map[class_id]}", linewidth=2.5)
    ax.axvspan(0.0, trial_duration, color='red', alpha=0.1)
    ax.axvline(0.0, color='red', linestyle='--', alpha=0.7)
    ax.set_xlim(-pad, trial_duration + pad)
    title = parcel_template[parcel_idx] if parcel_template is not None else f'Parcel {parcel_idx}'
    ax.set_title(f'Parcel: {title}')

for ax in axes[n_cols * (n_rows - 1):]:
    if ax.has_data():
        ax.set_xlabel('Time (s)')
for ax in axes[::n_cols]:
    if ax.has_data():
        ax.set_ylabel('Normalized amplitude')
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='center left', bbox_to_anchor=(0.8, 0.5), fontsize=30)
plt.tight_layout(rect=[0, 0, 0.8, 1])
plt.savefig(PROCESSED_DIR / f'grid_block_average_{DATASET_NAME}_{subject_id}_{delta_tag}.png', dpi=300)
plt.show()
